# %% [markdown]
# ## Healthy Food Recommendation System
# #### Vishnupriya Venkateswaran

# %% [markdown]
# #### This notebook contains the food recommender system which outputs a healthier alternative to the user input.

# %%
#Import required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read the datafile
final = pd.read_csv('/Users/vishnupriyavenkateswaran/Desktop/GWU_Sem4/Code/Machine_Learning/Healthy_Food_Recommendation_System/Data/Final_Nutrition.csv')

# %%
final.set_index('fdc_id', inplace=True, drop=False)

# %%
final.head()
# Out:
#         fdc_id        brand_owner  \
# fdc_id
# 356425  356425  G. T. Japan, Inc.
# 356426  356426       FRESH & EASY
# 356427  356427       FRESH & EASY
# 356428  356428       FRESH & EASY
# 356429  356429       FRESH & EASY
#
#                                               ingredients  serving_size  \
# fdc_id
# 356425  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...          40.0
# 356426  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...          37.0
# 356427  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...          34.0
# 356428  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...          35.0
# 356429  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...          37.0
#
#        serving_size_unit                 branded_food_category     data_type  \
# fdc_id
# 356425                 g             Ice Cream & Frozen Yogurt  branded_food
# 356426                 g  Ketchup, Mustard, BBQ & Cheese Sauce  branded_food
# 356427                 g  Ketchup, Mustard, BBQ & Cheese Sauce  branded_food
# 356428                 g  Ketchup, Mustard, BBQ & Cheese Sauce  branded_food
# 356429                 g  Ketchup, Mustard, BBQ & Cheese Sauce  branded_food
#
#                        description publication_date  cat_null     ...       \
# fdc_id                                                            ...
# 356425     MOCHI ICE CREAM BONBONS       2019-04-01     False     ...
# 356426     CHIPOTLE BARBECUE SAUCE       2019-04-01     False     ...
# 356427  HOT & SPICY BARBECUE SAUCE       2019-04-01     False     ...
# 356428              BARBECUE SAUCE       2019-04-01     False     ...
# 356429              BARBECUE SAUCE       2019-04-01     False     ...
#
#         fiber_grams  vitamin_a_IU  vitamin_c_MG  calcium_MG  iron_MG  sugar_G  \
# fdc_id
# 356425          0.0         0.000      0.050000        0.05      0.0  0.24000
# 356426          0.0         0.054      0.161667        0.00      0.0  0.30272
# 356427          0.0         0.000      0.000000        0.00      0.0  0.28232
# 356428          0.0         0.000      0.000000        0.00      0.0  0.22856
# 356429          0.0         0.000      0.000000        0.00      0.0  0.34592
#
#         sodium_MG   NRFNn.3  cluster  new_cluster
# fdc_id
# 356425   0.031250 -0.308750      NaN       1086.0
# 356426   0.292917 -0.379970      NaN       1162.0
# 356427   0.281667 -0.563987      NaN       1162.0
# 356428   0.404583 -0.633143      NaN       1162.0
# 356429   0.315417 -0.661337      NaN       1162.0
#
# [5 rows x 26 columns]

# %%
final.columns
# Out:
# Index(['fdc_id', 'brand_owner', 'ingredients', 'serving_size',
#        'serving_size_unit', 'branded_food_category', 'data_type',
#        'description', 'publication_date', 'cat_null', 'sat_fat_g',
#        'trans_fat_g', 'magnesium_mg', 'potassium_mg', 'mufa_grams',
#        'protein_grams', 'fiber_grams', 'vitamin_a_IU', 'vitamin_c_MG',
#        'calcium_MG', 'iron_MG', 'sugar_G', 'sodium_MG', 'NRFNn.3', 'cluster',
#        'new_cluster'],
#       dtype='object')

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

print(color.RED + 'Hello World !' + color.END)
# Out:
# Hello World !

# %%
#Healthy Food Recommender

q = input('Enter Food Here: ')
df = pd.DataFrame([])
print(final[final['description'].str.contains(q)]['description'])
inp = int(input('Choose Food Item: '))
cluster = final[final['new_cluster']==final['new_cluster'][inp]]
print(color.RED + color.BOLD + 
      f"Your original food selection was {final['description'][inp]} with a nutrition index of {final['NRFNn.3'][inp]:.2f}." + 
      color.END)
for i in cluster.index:
    if final['NRFNn.3'][i] > final['NRFNn.3'][inp]:
        df = df.append(pd.DataFrame({'ID': final['fdc_id'][i], 
                                     'Alternative Food Option': final['description'][i], 
                                     'Nutrition Index': final['NRFNn.3'][i], 
                                     'Protein %DV': final['protein_grams'][i]*100, 
                                     'Fiber %DV': final['fiber_grams'][i]*100, 
                                     'Monounsaturated Fat %DV': final['mufa_grams'][i]*100,
                                     'Vitamin A %DV': final['vitamin_a_IU'][i]*100, 
                                     'Vitamin C %DV': final['vitamin_c_MG'][i]*100, 
                                     'Calcium %DV': final['calcium_MG'][i]*100, 
                                     'Iron %DV': final['iron_MG'][i]*100, 
                                     'Potassium %DV': final['potassium_mg'][i]*100, 
                                     'Saturated Fat %DV': final['sat_fat_g'][i]*100, 
                                     'Trans Fat %DV': final['trans_fat_g'][i]*100, 
                                     'Sugar %DV': final['sugar_G'][i]*100, 
                                     'Sodium %DV': final['sodium_MG'][i]*100},
                                    index=[0]), ignore_index=True)
    else:
        pass
if df.empty:
    print("You selected the healthiest item!")
else:
    pd.set_option('display.max_colwidth', -1)
    df = df.round(2)
    df = df.sort_values(by='Nutrition Index', ascending=False)
    print(color.RED + color.BOLD + "Would you consider one of the following healthier options?" + color.END)
df.head()
# Out:
# Enter Food Here: Chicken
# fdc_id
# 344716    Pringles Crisps Bourbon Bbq Chicken 5.9oz
# 345061    Morningstar Farms Meal Solutions Chicken 10oz
# 345068    Morningstar Farms Meal Solutions Chicken 13.5oz
# 345756    Kellogg's Pringles Crisps Kickin Chicken Taco 5.5oz
# 350577    Rice A Roni Chicken & Mushroom 5.0 Ounce Paper Box.
# 350726    Rice A Roni Chicken & Garlic Flavor 5.9 Ounce Box
# 351050    Pasta Roni Chicken Fettuccine Pasta 4.7 Ounce Box
# 351376    Rice A Roni Lower Sodium Chicken 6.9 Ounce Paper Box
# 351951    Rice A Roni Chicken Fajita 5.6 Ounce Box
# 352583    Rice A Roni Chicken Flavor 6.9 Ounce Paper Box
# 352604    Rice A Roni Instant Chicken Flavor 1.97 Ounce Cup
# 353009    Near East Whole Grain Blends Chicken & Herb Rice 5.7 Ounce Paper Box
# 353434    Near East Roasted Vegetable & Chicken Long Grain & Wild Rice 6.3 Ounce Paper Box
# 353751    Rice A Roni Chicken Teriyaki 6.2 Ounce Paper Box
# 353866    Pasta Roni Chicken & Broccoli Linguine 4.7 Ounce Paper Box
# 354053    Near East Roasted Chicken & Garlic Rice Pilaf 6.3 Ounce Paper Box
# 354078    Near East Herbed Chicken Couscous Mix 5.7 Ounce Paper Box
# 355724    Progresso Gluten Free Chicken & Rice Noodle Soup
# 355927    Progresso Chicken Tortilla Soup with Tortilla Strips
# 355941    Progresso Chicken Noodle Soup with Oyster Crackers
# Name: description, Length: 343, dtype: object
# Choose Food Item: 355941
# Your original food selection was Progresso Chicken Noodle Soup with Oyster Crackers with a nutrition index of 0.01.
# Would you consider one of the following healthier options?
#        ID                    Alternative Food Option  Nutrition Index  \
# 7  356057  SWANSON SOUP CHICKEN NOODLE                0.97
# 8  356347  SWANSON SOUP VEGETABLE BEEF NOODLE         0.84
# 1  348848  Progresso Traditional Chicken Noodle Soup  0.25
# 2  348883  Progresso Light Vegetable & Noodle Soup    0.22
# 0  348565  Progresso Organic Chicken Noodle Soup      0.21
#
#    Protein %DV  Fiber %DV  Monounsaturated Fat %DV  Vitamin A %DV  \
# 7  30.40        30.4       0.00                     0.0
# 8  26.78        26.8       0.00                     0.0
# 1  5.78         1.6        2.05                     24.8
# 2  2.42         6.4        0.00                     12.1
# 0  4.94         1.6        1.05                     24.7
#
#    Vitamin C %DV  Calcium %DV  Iron %DV  Potassium %DV  Saturated Fat %DV  \
# 7  0.0            19.8         12.67     20.40          0.00
# 8  0.0            15.4         11.17     24.09          0.00
# 1  0.0            0.0          0.83      4.14           2.05
# 2  0.0            1.6          1.61      6.46           0.00
# 0  0.0            0.0          0.83      0.00           0.00
#
#    Trans Fat %DV  Sugar %DV  Sodium %DV
# 7  0.0            6.08       11.08
# 8  0.0            10.71      9.75
# 1  0.0            0.33       11.88
# 2  0.0            0.65       8.08
# 0  0.0            0.66       11.50

# %% [markdown]
# ### Hence the food recommender system takes the input ice cream and gives five alternative healthy options based on the nutrition index and clusters created using K-Means algorithm.

# %% [markdown]
# #### You can try this with different inputs to see the different healthy food recommendations
